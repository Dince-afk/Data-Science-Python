# %% [markdown]
# # Ted Talks and Relevance of Climate Change

# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("/Users/dinocuric/Documents/Datasets/ted-talks.csv")
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# ## Check data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %% [markdown]
# ## Missing values

# %% [markdown]
# No null values except one author missing.

# %%
df.isnull().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#                    title author           date  views  likes  \
# 3039  Year In Ideas 2015    NaN  December 2015    532     15
#
#                                           link
# 3039  https://ted.com/talks/year_in_ideas_2015

# %% [markdown]
# ## Format data

# %%
df.date
# Out:
# 0        December 2021
# 1        February 2022
# 2       September 2021
# 3         October 2021
# 4         October 2021
#              ...
# 5435     February 2006
# 5436     February 2006
# 5437     February 2006
# 5438     February 2006
# 5439     February 2006
# Name: date, Length: 5440, dtype: object

# %%
df.date = pd.to_datetime(df.date)
df.date
# Out:
# 0      2021-12-01
# 1      2022-02-01
# 2      2021-09-01
# 3      2021-10-01
# 4      2021-10-01
#           ...
# 5435   2006-02-01
# 5436   2006-02-01
# 5437   2006-02-01
# 5438   2006-02-01
# 5439   2006-02-01
# Name: date, Length: 5440, dtype: datetime64[ns]

# %% [markdown]
# ## Change figure size

# %%
plt.rcParams['figure.figsize'] = (12, 7)

# %% [markdown]
# ## Search for climate change pattern

# %%
filt = df.title.str.contains(r"[Cc]limate") | df.title.str.contains(r".nvironment...")
df_climate = df[filt]
df_climate
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 17              The ocean's ingenious climate solutions           Susan Ruffo
# 18    How we're reducing the climate impact of elect...              Tim Dunn
# 34    How to boost nature-based solutions to climate...         Zac Goldsmith
# ...                                                 ...                   ...
# 4956                         4 environmental 'heresies'         Stewart Brand
# 5226                 New thinking on the climate crisis               Al Gore
# 5280  A critical look at geoengineering against clim...           David Keith
# 5389       Global priorities bigger than climate change         Bjorn Lomborg
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df_no_climate = df.loc[~filt]
df_no_climate
# Out:
#                                                   title  \
# 1           The dark history of the overthrow of Hawaii
# 2        How play can spark new ideas for your business
# 4        Cement's carbon problem — and 2 ways to fix it
# 5     The tragedy of air pollution — and an urgent d...
# 6                        The myth of Narcissus and Echo
# ...                                                 ...
# 5434             Behind the design of Seattle's library
# 5435                    The best stats you've ever seen
# 5436                        Do schools kill creativity?
# 5437                                Greening the ghetto
# 5438                                   Simplicity sells
#
#                           author       date     views    likes  \
# 1                  Sydney Iaukea 2022-02-01    214000     6400
# 2                  Martin Reeves 2021-09-01    412000    12000
# 4                Mahendra Singhi 2021-10-01      2400       72
# ...

# %%
c_climate = df_climate.title.groupby(df_climate.date.dt.year).agg("count")
c_climate
# Out:
# date
# 2005     1
# 2006     1
# 2007     1
# 2008     1
# 2009     2
# 2010     2
# 2012     2
# 2013     2
# 2014     2
# 2015     3
# 2016     4
# 2017     4
# 2018     4
# 2019    16
# 2020    23
# 2021    27
# 2022     1
# Name: title, dtype: int64

# %%
c_no_climate = df_no_climate.title.groupby(df_no_climate.date.dt.year).count()
c_no_climate
# Out:
# date
# 1970      2
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     26
# 2003     34
# 2004     33
# 2005     64
# 2006     48
# 2007    112
# 2008     83
# 2009    231
# 2010    265
# 2011    271
# 2012    300
# 2013    386
# 2014    355
# 2015    374
# 2016    395
# 2017    491
# 2018    469
# 2019    528
# 2020    478
# 2021    363
# 2022     19
# Name: title, dtype: int64

# %% [markdown]
# The bar chart shows us that there has been a stark increase in climate change and environmental issues related TED talks over the last three years.

# %%
plt.figure(figsize=(10,5))
c_climate.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Create a counts table with climate topics and rest topics.

# %%
counts_table = pd.concat([c_climate, c_no_climate], axis=1, names=["climate", "non_climate"])
counts_table.sort_index(inplace=True)
counts_table.columns = ["climate", "non_climate"]
counts_table = counts_table.loc[2000:2022]
counts_table
# Out:
#       climate  non_climate
# date
# 2001      NaN            5
# 2002      NaN           26
# 2003      NaN           34
# 2004      NaN           33
# 2005      1.0           64
# 2006      1.0           48
# 2007      1.0          112
# 2008      1.0           83
# 2009      2.0          231
# 2010      2.0          265
# 2011      NaN          271
# 2012      2.0          300
# 2013      2.0          386
# 2014      2.0          355
# 2015      3.0          374
# 2016      4.0          395
# 2017      4.0          491
# 2018      4.0          469
# 2019     16.0          528
# 2020     23.0          478
# 2021     27.0          363
# 2022      1.0           19

# %%
width = 0.35       # the width of the bars: can also be len(x) sequence
plt.figure(figsize=(10,5))
plt.bar(counts_table.index, counts_table.non_climate, width, label='Rest')
plt.bar(counts_table.index, counts_table.climate, width, bottom=counts_table.non_climate ,label='Climate')

plt.ylabel('Counts')
plt.title('Counts by Climate and Rest')
plt.legend()

# %% [markdown]
# ## How did median views and likes for climate related talks change over time?

# %% [markdown]
# Climate related talks get more views periodically.

# %%
plt.figure(figsize=(10,5))
df_no_climate["views"].groupby(df_no_climate.date.dt.year).median().plot()
df_climate["views"].groupby(df.date.dt.year).median().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# The same with means instead of medians. There seem to be more extreme data points for

# %%
plt.figure(figsize=(10,5))
df_no_climate["views"].groupby(df_no_climate.date.dt.year).mean().plot()
df_climate["views"].groupby(df.date.dt.year).mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# The peak year for climate talks was 2013, followed by 2006 and 2018.

# %%
df_climate.groupby(df_climate.date.dt.year).median().sort_values(["views"], ascending=False)
# Out:
#           views     likes
# date
# 2013  4650000.0  140500.0
# 2006  3600000.0  109000.0
# 2018  2900000.0   87500.0
# 2008  2200000.0   68000.0
# 2019  2050000.0   62000.0
# 2005  1700000.0   53000.0
# 2017  1450000.0   43500.0
# 2007  1400000.0   44000.0
# 2012  1400000.0   42000.0
# 2020  1300000.0   39000.0
# 2015  1300000.0   39000.0
# 2016  1300000.0   39500.0
# 2010  1178500.0   35000.0
# 2014  1088500.0   33000.0
# 2021  1000000.0   32000.0
# 2009   916000.0   27500.0
# 2022    96000.0    2900.0

# %%
df_climate.groupby(df_climate.date.dt.year).median().plot(kind = "bar")
plt.gca().ticklabel_format(axis='y', style='plain')
plt.title("Median Views and Likes for Climate Talks")
# Out:
# Text(0.5, 1.0, 'Median Views and Likes for Climate Talks')

# %% [markdown]
# ## Let's now plot the views difference of climate talks and rest talks

# %%
df_climate.groupby(df_climate.date.dt.year).median()
df_no_climate.groupby(df_no_climate.date.dt.year).median()

count_table_numerics = pd.concat([
    df_climate["views"].groupby(df_climate.date.dt.year).median(), 
    df_climate["likes"].groupby(df_climate.date.dt.year).median(), 
    df_no_climate["views"].groupby(df_no_climate.date.dt.year).median(),
    df_no_climate["likes"].groupby(df_no_climate.date.dt.year).median()
    ],
    axis=1,
    keys=[
        "climate_views",
        "climate_likes",
        "rest_views",
        "rest_likes"
    ])
count_table_numerics.sort_index(inplace=True)
count_table_numerics
# Out:
#       climate_views  climate_likes  rest_views  rest_likes
# date
# 1970            NaN            NaN    126000.0      3750.0
# 1972            NaN            NaN   1300000.0     41000.0
# 1983            NaN            NaN    690000.0     20000.0
# 1984            NaN            NaN   1100000.0     33000.0
# 1990            NaN            NaN    723000.0     21000.0
# 1991            NaN            NaN    327000.0      9800.0
# 1994            NaN            NaN    699000.0     20000.0
# 1998            NaN            NaN    794000.0     24000.0
# 2001            NaN            NaN    527000.0     15000.0
# 2002            NaN            NaN    858500.0     25000.0
# 2003            NaN            NaN    988500.0     29500.0
# 2004            NaN            NaN   1600000.0     49000.0
# 2005      1700000.0        53000.0   1200000.0     38000.0
# 2006      3600000.0       109000.0   1250000.0     39000.0
# 2007      1400000.0        44000.0    910000.0     26500.0
# ...

# %%
count_table_numerics.loc[2004:2022].plot(kind="bar", color = ["darkgreen", "springgreen", "black", "gainsboro" ])
plt.gca().ticklabel_format(axis='y', style='plain')

# %%
count_table_numerics[["climate_views", "rest_views"]].loc[2004:2022]
# Out:
#       climate_views  rest_views
# date
# 2004            NaN   1600000.0
# 2005      1700000.0   1200000.0
# 2006      3600000.0   1250000.0
# 2007      1400000.0    910000.0
# 2008      2200000.0   1300000.0
# 2009       916000.0   1000000.0
# 2010      1178500.0   1200000.0
# 2011            NaN   1100000.0
# 2012      1400000.0   1300000.0
# 2013      4650000.0   1400000.0
# 2014      1088500.0   1400000.0
# 2015      1300000.0   1700000.0
# 2016      1300000.0   1400000.0
# 2017      1450000.0   1300000.0
# 2018      2900000.0   1600000.0
# 2019      2050000.0   1750000.0
# 2020      1300000.0   1200000.0
# 2021      1000000.0   1100000.0
# 2022        96000.0    456000.0

# %%
count_table_numerics[["climate_views", "rest_views"]].loc[2004:2022].plot(kind="bar", color = ["darkgreen", "black"])
plt.gca().ticklabel_format(axis='y', style='plain')
